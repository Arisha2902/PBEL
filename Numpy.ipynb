# %% [markdown]
# <a href="https://colab.research.google.com/github/coderanandmaurya/PBEL/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# NumPy is a fundamental package for scientific computing with Python, providing support for large, multi-dimensional arrays and matrices, along with a collection of high-level mathematical functions to operate on these arrays.
#  It is an open-source library, developed and maintained publicly on GitHub by a vibrant, responsive, and diverse community.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
# def numpy(input , type)

# %%
a=np.array([1,2,3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.ndim
# Out:
# 1

# %%
np.arange(0,10,2)   # start end steps
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.random.randint(0,10,5)
# Out:
# array([4, 8, 0, 1, 2])

# %%
np.random.rand(2,3,4)
# Out:
# array([[[0.9412193 , 0.11864465, 0.52737364, 0.5448643 ],
#         [0.82434614, 0.65963694, 0.52617554, 0.09506183],
#         [0.24841656, 0.85147857, 0.40817495, 0.64911118]],
#
#        [[0.52335298, 0.4069154 , 0.69262985, 0.79797153],
#         [0.17377963, 0.40154544, 0.19691784, 0.59192164],
#         [0.04472351, 0.00640515, 0.0637984 , 0.52087729]]])

# %%
# # random guessing game where you to ask user to guess the correct number guess wrong tell add or sub number
# b=int(input("write any number "))
# print("number is: ", b)

# %%
b=int(input("write any number"))
print("the number is:", b)
c=(np.random.randint(0,100))
print(c)
if b<c:
  print("add number")
else:
  print("sub number")
# Out:
# write any number55
# the number is: 55
# 93
# add number

# %%
#saud
import numpy as np

num = np.random.randint(1, 11)

guess = int(input("Guess a number between 1 and 10: "))

if guess == num:
    print("Correct! You guessed it.")
elif guess < num:
    print("Wrong! Try a bigger number.")
else:
    print("Wrong! Try a smaller number.")
# Out:
# Guess a number between 1 and 10: 56
# Wrong! Try a smaller number.

# %%
import numpy as np

# %%
a=np.ones((7,5),dtype=int)

# %%
a.shape
# Out:
# (7, 5)

# %%
a.ndim
# Out:
# 2

# %%
b=np.zeros((3,4),dtype=int)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(a)

# %%
# black and white image
a=np.array([[0,3,0,1.1],[1,5,1,0]])

# %%
plt.imshow(a)

# %%
a.shape
# Out:
# (2, 4)

# %%
arr=np.random.randint(0,10,24)

# %%
arr.shape
# Out:
# (24,)

# %%
arr=arr.reshape(2,12)   #=24

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(24,1)
# Out:
# array([[6],
#        [6],
#        [8],
#        [9],
#        [1],
#        [3],
#        [3],
#        [3],
#        [5],
#        [3],
#        [3],
#        [3],
#        [7],
#        [9],
#        [9],
#        [2],
#        [5],
#        [8],
#        [3],
#        [2],
#        [6],
#        [5],
#        [1],
#        [9]])

# %%
arr.ravel()
# Out:
# array([6, 6, 8, 9, 1, 3, 3, 3, 5, 3, 3, 3, 7, 9, 9, 2, 5, 8, 3, 2, 6, 5,
#        1, 9])

# %%
arr
# Out:
# array([[6, 6, 8, 9, 1, 3, 3, 3, 5, 3, 3, 3],
#        [7, 9, 9, 2, 5, 8, 3, 2, 6, 5, 1, 9]])

# %%
arr+1
# Out:
# array([[ 7,  7,  9, 10,  2,  4,  4,  4,  6,  4,  4,  4],
#        [ 8, 10, 10,  3,  6,  9,  4,  3,  7,  6,  2, 10]])

# %%
arr.argmin()
# Out:
# np.int64(4)

# %%
arr
# Out:
# array([[6, 6, 8, 9, 1, 3, 3, 3, 5, 3, 3, 3],
#        [7, 9, 9, 2, 5, 8, 3, 2, 6, 5, 1, 9]])

# %%
arr.min()
# Out:
# np.int64(1)

# %%
arr.max()
# Out:
# np.int64(9)

# %%
arr.mean()
# Out:
# np.float64(4.958333333333333)

# %%
np.median(arr)
# Out:
# np.float64(5.0)

# %%
np.sort(arr)
# Out:
# array([[1, 3, 3, 3, 3, 3, 3, 5, 6, 6, 8, 9],
#        [1, 2, 2, 3, 5, 5, 6, 7, 8, 9, 9, 9]])
